# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# 2024-06-02 16:51:27.707262: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 1800
classifications_to_replace = classification_counts[classification_counts <= cutoff].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_encoded = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_encoded.drop(columns = ['IS_SUCCESSFUL'])
y = application_df_encoded['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()
number_input_features = len(X_train_scaled[0])

hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 45

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer2, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4400
#
#  dense_1 (Dense)             (None, 45)                4545
#
#  dense_2 (Dense)             (None, 1)                 46
#
# =================================================================
# Total params: 8991 (35.12 KB)
# Trainable params: 8991 (35.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 170)
# Out:
# Epoch 1/170
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5693 - accuracy: 0.7210
# Epoch 2/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5551 - accuracy: 0.7283
# Epoch 3/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5530 - accuracy: 0.7297
# Epoch 4/170
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5511 - accuracy: 0.7303
# Epoch 5/170
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7321
# Epoch 6/170
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5484 - accuracy: 0.7321
# Epoch 7/170
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7327
# Epoch 8/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7327
# Epoch 9/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5461 - accuracy: 0.7329
# Epoch 10/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5460 - accuracy: 0.7329
# Epoch 11/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5454 - accuracy: 0.7330
# Epoch 12/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7340
# Epoch 13/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7343
# Epoch 14/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7346
# Epoch 15/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7350
# Epoch 16/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7357
# Epoch 17/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7347
# Epoch 18/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7346
# Epoch 19/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7362
# Epoch 20/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7361
# Epoch 21/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7359
# Epoch 22/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7353
# Epoch 23/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7361
# Epoch 24/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7366
# Epoch 25/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7368
# Epoch 26/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5407 - accuracy: 0.7371
# Epoch 27/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7365
# Epoch 28/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7367
# Epoch 29/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7369
# Epoch 30/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7374
# Epoch 31/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7371
# Epoch 32/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7378
# Epoch 33/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7375
# Epoch 34/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7386
# Epoch 35/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7378
# Epoch 36/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7377
# Epoch 37/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7371
# Epoch 38/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7381
# Epoch 39/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7383
# Epoch 40/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7378
# Epoch 41/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7379
# Epoch 42/170
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7384
# Epoch 43/170
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7378
# Epoch 44/170
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7387
# Epoch 45/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7378
# Epoch 46/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7375
# Epoch 47/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7387
# Epoch 48/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7387
# Epoch 49/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7388
# Epoch 50/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 51/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7382
# Epoch 52/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7386
# Epoch 53/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7377
# Epoch 54/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7397
# Epoch 55/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7386
# Epoch 56/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7388
# Epoch 57/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7390
# Epoch 58/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7392
# Epoch 59/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7399
# Epoch 60/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7393
# Epoch 61/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7394
# Epoch 62/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7390
# Epoch 63/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7393
# Epoch 64/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7390
# Epoch 65/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7395
# Epoch 66/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 67/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 68/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7394
# Epoch 69/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7399
# Epoch 70/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7397
# Epoch 71/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7397
# Epoch 72/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7395
# Epoch 73/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 74/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7391
# Epoch 75/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7390
# Epoch 76/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7392
# Epoch 77/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7398
# Epoch 78/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7403
# Epoch 79/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 80/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7400
# Epoch 81/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7406
# Epoch 82/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7400
# Epoch 83/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7397
# Epoch 84/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7399
# Epoch 85/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7403
# Epoch 86/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 87/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7393
# Epoch 88/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7395
# Epoch 89/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7398
# Epoch 90/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7408
# Epoch 91/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 92/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7405
# Epoch 93/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7394
# Epoch 94/170
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 95/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7403
# Epoch 96/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 97/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7408
# Epoch 98/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 99/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7408
# Epoch 100/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7406
# Epoch 101/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7409
# Epoch 102/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7404
# Epoch 103/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7403
# Epoch 104/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7396
# Epoch 105/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 106/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7400
# Epoch 107/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7399
# Epoch 108/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7408
# Epoch 109/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7399
# Epoch 110/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7402
# Epoch 111/170
# 804/804 [==============================] - 1s 968us/step - loss: 0.5332 - accuracy: 0.7406
# Epoch 112/170
# 804/804 [==============================] - 1s 973us/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 113/170
# 804/804 [==============================] - 1s 969us/step - loss: 0.5335 - accuracy: 0.7399
# Epoch 114/170
# 804/804 [==============================] - 1s 946us/step - loss: 0.5332 - accuracy: 0.7402
# Epoch 115/170
# 804/804 [==============================] - 1s 988us/step - loss: 0.5333 - accuracy: 0.7410
# Epoch 116/170
# 804/804 [==============================] - 1s 958us/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 117/170
# 804/804 [==============================] - 1s 931us/step - loss: 0.5329 - accuracy: 0.7411
# Epoch 118/170
# 804/804 [==============================] - 1s 919us/step - loss: 0.5331 - accuracy: 0.7404
# Epoch 119/170
# 804/804 [==============================] - 1s 960us/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 120/170
# 804/804 [==============================] - 1s 967us/step - loss: 0.5329 - accuracy: 0.7408
# Epoch 121/170
# 804/804 [==============================] - 1s 925us/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 122/170
# 804/804 [==============================] - 1s 907us/step - loss: 0.5331 - accuracy: 0.7409
# Epoch 123/170
# 804/804 [==============================] - 1s 997us/step - loss: 0.5326 - accuracy: 0.7400
# Epoch 124/170
# 804/804 [==============================] - 1s 908us/step - loss: 0.5328 - accuracy: 0.7402
# Epoch 125/170
# 804/804 [==============================] - 1s 906us/step - loss: 0.5324 - accuracy: 0.7408
# Epoch 126/170
# 804/804 [==============================] - 1s 886us/step - loss: 0.5328 - accuracy: 0.7407
# Epoch 127/170
# 804/804 [==============================] - 1s 874us/step - loss: 0.5328 - accuracy: 0.7408
# Epoch 128/170
# 804/804 [==============================] - 1s 900us/step - loss: 0.5323 - accuracy: 0.7408
# Epoch 129/170
# 804/804 [==============================] - 1s 935us/step - loss: 0.5328 - accuracy: 0.7411
# Epoch 130/170
# 804/804 [==============================] - 1s 880us/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 131/170
# 804/804 [==============================] - 1s 887us/step - loss: 0.5327 - accuracy: 0.7399
# Epoch 132/170
# 804/804 [==============================] - 1s 919us/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 133/170
# 804/804 [==============================] - 1s 875us/step - loss: 0.5328 - accuracy: 0.7401
# Epoch 134/170
# 804/804 [==============================] - 1s 892us/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 135/170
# 804/804 [==============================] - 1s 887us/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 136/170
# 804/804 [==============================] - 1s 887us/step - loss: 0.5324 - accuracy: 0.7412
# Epoch 137/170
# 804/804 [==============================] - 1s 897us/step - loss: 0.5321 - accuracy: 0.7416
# Epoch 138/170
# 804/804 [==============================] - 1s 862us/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 139/170
# 804/804 [==============================] - 1s 868us/step - loss: 0.5326 - accuracy: 0.7407
# Epoch 140/170
# 804/804 [==============================] - 1s 858us/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 141/170
# 804/804 [==============================] - 1s 874us/step - loss: 0.5326 - accuracy: 0.7400
# Epoch 142/170
# 804/804 [==============================] - 1s 870us/step - loss: 0.5325 - accuracy: 0.7407
# Epoch 143/170
# 804/804 [==============================] - 1s 860us/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 144/170
# 804/804 [==============================] - 1s 851us/step - loss: 0.5321 - accuracy: 0.7408
# Epoch 145/170
# 804/804 [==============================] - 1s 905us/step - loss: 0.5319 - accuracy: 0.7411
# Epoch 146/170
# 804/804 [==============================] - 1s 884us/step - loss: 0.5328 - accuracy: 0.7411
# Epoch 147/170
# 804/804 [==============================] - 1s 911us/step - loss: 0.5324 - accuracy: 0.7408
# Epoch 148/170
# 804/804 [==============================] - 1s 869us/step - loss: 0.5319 - accuracy: 0.7414
# Epoch 149/170
# 804/804 [==============================] - 1s 866us/step - loss: 0.5321 - accuracy: 0.7408
# Epoch 150/170
# 804/804 [==============================] - 1s 867us/step - loss: 0.5322 - accuracy: 0.7411
# Epoch 151/170
# 804/804 [==============================] - 1s 867us/step - loss: 0.5343 - accuracy: 0.7413
# Epoch 152/170
# 804/804 [==============================] - 1s 861us/step - loss: 0.5325 - accuracy: 0.7409
# Epoch 153/170
# 804/804 [==============================] - 1s 824us/step - loss: 0.5317 - accuracy: 0.7417
# Epoch 154/170
# 804/804 [==============================] - 1s 851us/step - loss: 0.5315 - accuracy: 0.7415
# Epoch 155/170
# 804/804 [==============================] - 1s 851us/step - loss: 0.5318 - accuracy: 0.7408
# Epoch 156/170
# 804/804 [==============================] - 1s 861us/step - loss: 0.5322 - accuracy: 0.7411
# Epoch 157/170
# 804/804 [==============================] - 1s 867us/step - loss: 0.5320 - accuracy: 0.7408
# Epoch 158/170
# 804/804 [==============================] - 1s 854us/step - loss: 0.5316 - accuracy: 0.7412
# Epoch 159/170
# 804/804 [==============================] - 1s 859us/step - loss: 0.5316 - accuracy: 0.7405
# Epoch 160/170
# 804/804 [==============================] - 1s 862us/step - loss: 0.5317 - accuracy: 0.7404
# Epoch 161/170
# 804/804 [==============================] - 1s 861us/step - loss: 0.5321 - accuracy: 0.7405
# Epoch 162/170
# 804/804 [==============================] - 1s 865us/step - loss: 0.5313 - accuracy: 0.7415
# Epoch 163/170
# 804/804 [==============================] - 1s 853us/step - loss: 0.5317 - accuracy: 0.7404
# Epoch 164/170
# 804/804 [==============================] - 1s 916us/step - loss: 0.5318 - accuracy: 0.7413
# Epoch 165/170
# 804/804 [==============================] - 1s 896us/step - loss: 0.5316 - accuracy: 0.7414
# Epoch 166/170
# 804/804 [==============================] - 1s 916us/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 167/170
# 804/804 [==============================] - 1s 972us/step - loss: 0.5323 - accuracy: 0.7414
# Epoch 168/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7416
# Epoch 169/170
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7405
# Epoch 170/170
# 804/804 [==============================] - 1s 893us/step - loss: 0.5321 - accuracy: 0.7408

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5745 - accuracy: 0.7291 - 269ms/epoch - 1ms/step
# Loss: 0.5744779109954834, Accuracy: 0.7290962338447571

# %%
# Export our model to HDF5 file
nn.save('Models/AlphabetSoupCharity_Optimization3.h5')
# Out:
# /Users/CaseyWaggoner/miniconda3/envs/dev/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
